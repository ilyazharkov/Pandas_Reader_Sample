# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x):
    return np.sin(x / 5) * np.exp(x / 10) + 5 * np.exp(-x / 2)
x = np.arange(0., 32., 0.1)
y = f(x)
plt.plot(x, y)

# %%
import numpy as np
import matplotlib.pyplot as plt
import Subroutines.Approximation as aprx
input_x=np.array([1.,8.,15.,22.,27.])
input_f = f(input_x)
approximated = aprx.approximation_polynomial(x, y, dist=2, rate=4)
approximated_2 = aprx.approximation_polynomial(x, input_f, points=input_x, dist=2, rate=4)
weights = np.polyfit(x=x, y=y, deg=4)
approximated_3 = np.polyval(weights, x)
plt.plot(x, y)
#plt.plot(x, approximated)
#plt.plot(x, approximated_2)
plt.plot(x, approximated_3)
plt.show()
